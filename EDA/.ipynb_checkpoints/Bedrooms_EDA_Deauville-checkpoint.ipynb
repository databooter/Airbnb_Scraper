# %%
# importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# setting global visualization styles
sns.set_style("white")
sns.set_palette('Blues')
sns.set(rc={'figure.figsize':(12,7)})

# %%
# reading all scraped json files (each a respective price range containing >=300 listings) into their own respective dfs
d60 = pd.read_json(r'C:\Users\bdmul\Documents\Airbnb_scraper\Scraped Data\deauville_60.json')
d60_75 = pd.read_json(r'C:\Users\bdmul\Documents\Airbnb_scraper\Scraped Data\deauville_60_75.json')
d75_93 = pd.read_json(r'C:\Users\bdmul\Documents\Airbnb_scraper\Scraped Data\deauville_75_93.json')
d93_115 = pd.read_json(r'C:\Users\bdmul\Documents\Airbnb_scraper\Scraped Data\deauville_93_115.json')
d115_140 = pd.read_json(r'C:\Users\bdmul\Documents\Airbnb_scraper\Scraped Data\deauville_115_140.json')
d140_180 = pd.read_json(r'C:\Users\bdmul\Documents\Airbnb_scraper\Scraped Data\deauville_140_180.json')
d180_290 = pd.read_json(r'C:\Users\bdmul\Documents\Airbnb_scraper\Scraped Data\deauville_180_290.json')
d290 = pd.read_json(r'C:\Users\bdmul\Documents\Airbnb_scraper\Scraped Data\deauville_290.json')

# %%
# combining all dataframes into one
dfs = [d60, d60_75, d75_93, d93_115, d115_140, d140_180, d180_290, d290]
listings = pd.concat([d60, d60_75, d75_93, d93_115, d115_140, d140_180, d180_290, d290]).drop_duplicates().reset_index(drop=True)
listings.shape
# Out:
# (2209, 9)

# %%
# removing € from the 'price' field and changing type to integer to facilitate manipulation
listings['price'] = listings['price'].replace('[\€\,\.]', '', regex=True).astype(int)

# %%
listings
# Out:
#                                                    name  \
# 0                                                Studio
# 1                            Les Marinas for 2 persons.
# 2        Mini duplex aux Marinas de Deauville - vue mer
# 3                             Studio Deauville Rousseau
# 4                          Charmant appartement vue mer
# ...                                                 ...
# 2204        Le Green de Deauville, Résidence du Golf***
# 2205  House with 3 bedrooms in Saint-Arnoult, with e...
# 2206                                  Together, 12 lits
# 2207                          A 30 METRES DE LA PLAGE !
# 2208                             3 P au pieds de la mer
#
#                                          header  \
# 0               Entire rental unit in Deauville
# 1     Entire rental unit in Deauville-Trouville
# 2                 Entire apartment in Deauville
# 3               Entire rental unit in Deauville
# ...

# %%
# checking for outliers in 'price' field
listings.price.describe().round()
# Out:
# count    2209.0
# mean      171.0
# std       246.0
# min        26.0
# 25%        79.0
# 50%       119.0
# 75%       182.0
# max      8226.0
# Name: price, dtype: float64

# %%
# finding and removing outlier price at index location: 8226
listings[listings.price == 8226.0]
listings = listings.drop([2187])

# %%
# checking the types and frequency of bedrooms 
listings['bedrooms'].value_counts()
# Out:
# 1 bedroom     942
# 2 bedrooms    458
# Studio        395
# 3 bedrooms    227
# 4 bedrooms    113
# 5 bedrooms     40
# 6 bedrooms     19
# 7 bedrooms     10
# 8 bedrooms      4
# Name: bedrooms, dtype: int64

# %%
# replacing 'Studio' with '0' for easier manipulation
listings['bedrooms'] = listings['bedrooms'].replace('Studio', '0')
listings['bedrooms'] = listings['bedrooms'].replace(' bedrooms*', '', regex=True).astype(int)
listings['bedrooms'].value_counts()
# Out:
# 1    942
# 2    458
# 0    395
# 3    227
# 4    113
# 5     40
# 6     19
# 7     10
# 8      4
# Name: bedrooms, dtype: int64

# %%
# finding mean nightly rate per number of bedrooms
mean_price_by_bedrooms = listings.groupby(['bedrooms']).price.mean().round().reset_index()
mean_price_by_bedrooms
# Out:
#    bedrooms   price
# 0         0    85.0
# 1         1   108.0
# 2         2   167.0
# 3         3   254.0
# 4         4   423.0
# 5         5   553.0
# 6         6   872.0
# 7         7  1032.0
# 8         8  1118.0

# %%
# countplot to visualize frequency of bedrooms in all listings

# sns.set_palette("Blues", len(mean_price_by_bedrooms))
sns.set_style('white')
sns.set_style("ticks")

ax = sns.countplot(x='bedrooms', data=listings, color='cornflowerblue')
plt.title('Listing Frequency - Deauville, France', fontsize=16)
plt.ylabel('Count',  fontsize=13)
plt.xlabel('Bedrooms', fontsize=13)
sns.despine(bottom=True)

for p in ax.patches:
    # get the height of each bar
    height = p.get_height()
    # adding text to each bar
    ax.text(x = p.get_x()+(p.get_width()/2), # x-coordinate position of data label, padded to be in the middle of the bar
    y = height+10, # y-coordinate position of data label, padded 100 above bar
    s = '{:.0f}'.format(height), # data label, formatted to ignore decimals
    ha = 'center') # sets horizontal alignment (ha) to center

plt.savefig("Bedroom_Frequency.jpg")
plt.show()

# %%
# countplot to visualize frequency of bedrooms in all listings

# sns.set_palette("Blues", len(mean_price_by_bedrooms))
sns.set_style('white')
sns.set_style("ticks")

ax = sns.countplot(x='bedrooms', data=listings[listings['bedrooms'] != 1], color='gainsboro')
ticks = ax.get_xticks()
ticklabels = ax.get_xticklabels()
lim = ax.get_xlim()

sns.countplot(x='bedrooms', data=listings[listings['bedrooms'] == 1], color='cornflowerblue')
ax.set_xlim(lim)
ax.set_xticks(ticks)
ax.set_xticklabels(ticklabels)

plt.title('Lisiting Frequency - Deauville, France', fontsize=16)
plt.ylabel('Count',  fontsize=13)
plt.xlabel('Bedrooms', fontsize=13)
sns.despine(bottom=True)

for p in ax.patches:
    # get the height of each bar
    height = p.get_height()
    # adding text to each bar
    ax.text(x = p.get_x()+(p.get_width()/2), # x-coordinate position of data label, padded to be in the middle of the bar
    y = height+10, # y-coordinate position of data label, padded 100 above bar
    s = '{:.0f}'.format(height), # data label, formatted to ignore decimals
    ha = 'center') # sets horizontal alignment (ha) to center

plt.savefig("Bedroom_Frequency_1_bedroom.jpg")
plt.show()

# %%
# listing size proportion of market
listings['bedrooms'].value_counts(normalize=True).round(3).sort_index()
# Out:
# 0    0.179
# 1    0.427
# 2    0.207
# 3    0.103
# 4    0.051
# 5    0.018
# 6    0.009
# 7    0.005
# 8    0.002
# Name: bedrooms, dtype: float64

# %%
# barplot to visualize the mean nightly rate, by bedroom

ax = sns.barplot(data=mean_price_by_bedrooms, x='bedrooms', y='price')
plt.ylabel('Price (€)',  fontsize=13)
plt.xlabel('Bedrooms', fontsize=13)
plt.title('Mean Nightly Rate - Deauville, France', fontsize=16)

for p in ax.patches:
    # get the height of each bar
    height = p.get_height()
    # adding text to each bar
    ax.text(x = p.get_x()+(p.get_width()/2), # x-coordinate position of data label, padded to be in the middle of the bar
    y = height+10, # y-coordinate position of data label, padded 100 above bar
    s = '{:.0f}'.format(height), # data label, formatted to ignore decimals
    ha = 'center') # sets horizontal alignment (ha) to center
    
sns.despine(bottom=True)
sns.set_palette("Blues", len(mean_price_by_bedrooms))
sns.set_style("ticks")

plt.savefig("Mean_nightly_rate_Deauville.jpg")
plt.show()

# %%
# catplot to visualize the spread and frequency of the nightly rate, by bedroom
sns.reset_defaults()
sns.catplot(data=listings, x='bedrooms', y='price')
plt.ylabel('Price (€)',  fontsize=13)
plt.xlabel('Bedrooms', fontsize=13)
plt.title('One Bedroom Nightly Rate - Deauville, France', fontsize=16)
# plt.savefig("Mean_nightly_rate_Deauville.jpg")
plt.show()

# %%
# Nine Violin Subplots to visualize the price shape distribution of each bedroom count category
fig, axes = plt.subplots(3, 3, figsize=(18, 10))

fig.suptitle('Price Distribution Shape', fontsize=16)

sns.violinplot(ax=axes[0, 0], data=listings[listings['bedrooms'] == 0], x='bedrooms', y='price')
sns.violinplot(ax=axes[0, 1], data=listings[listings['bedrooms'] == 1], x='bedrooms', y='price')
sns.violinplot(ax=axes[0, 2], data=listings[listings['bedrooms'] == 2], x='bedrooms', y='price')
sns.violinplot(ax=axes[1, 0], data=listings[listings['bedrooms'] == 3], x='bedrooms', y='price')
sns.violinplot(ax=axes[1, 1], data=listings[listings['bedrooms'] == 4], x='bedrooms', y='price')
sns.violinplot(ax=axes[1, 2], data=listings[listings['bedrooms'] == 5], x='bedrooms', y='price')
sns.violinplot(ax=axes[2, 0], data=listings[listings['bedrooms'] == 6], x='bedrooms', y='price')
sns.violinplot(ax=axes[2, 1], data=listings[listings['bedrooms'] == 7], x='bedrooms', y='price')
sns.violinplot(ax=axes[2, 2], data=listings[listings['bedrooms'] == 8], x='bedrooms', y='price')
plt.show()

# %%
sns.boxplot(data=listings[listings['bedrooms'] == 1], x='price')
plt.show()

# %%
one_br = listings[listings["bedrooms"] == 1]
one_br[one_br['price'] > 460]
one_br = one_br.drop([2197, 2201, 2206])
# listings[listings.price == 8226.0]
# listings = listings.drop([2187])

# %%
one_br_median_price = one_br.price.median()
one_br_75 = np.quantile(one_br.price, 0.75)
one_br_25 = np.quantile(one_br.price, 0.25)
# one_br_97 = np.quantile(one_br.price, 0.975)
# one_br_3 = np.quantile(one_br.price, 0.03)

# %%
# one bedroom kdeplot
# sns.set_palette("Blues", len(mean_price_by_bedrooms))
sns.reset_defaults()
sns.set_style("white")
sns.set_style("ticks")
# sns.kdeplot(data=listings[listings["bedrooms"] ==0], x='price')
sns.kdeplot(data=one_br, x='price', color='cornflowerblue', fill=True, alpha=0.1, bw_method=0.1)

plt.axvline(one_br_median_price, color ='darkorange', linestyle='dashed', linewidth='1')
plt.axvline(one_br_75, color ='darkorange', linestyle='dashed', linewidth='1')
plt.axvline(one_br_25, color ='darkorange', linestyle='dashed', linewidth='1')

plt.title('Nightly Rate Percentiles - Deauville, France', fontsize=16)
plt.xlabel('Price (€)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.xticks([0, 25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350])

plt.annotate('25%', xy = (54, .001), color='k', fontsize=9)
plt.annotate('50%', xy = (78, .002), color = 'k', fontsize=9)
plt.annotate('75%', xy = (108, .0027), color = 'k', fontsize=9)
sns.despine(top=True)
plt.savefig("Nightly_Rate_Percentiles.jpg")
plt.show()

# %%
print(f'50% of one-bedroom units in Deauville are priced between \n{one_br_25} and {one_br_75} euros per night')
# Out:
# 50% of one-bedroom units in Deauville are priced between
# 73.0 and 128.0 euros per night

# %%
one_br.bathrooms.value_counts()
# Out:
# 1.0    891
# 1.5     39
# 2.0     11
# 3.5      1
# Name: bathrooms, dtype: int64

# %%
# one_br['bathrooms'] = one_br['bathrooms'].replace('1 private bathroom', '1')
# one_br['bathrooms'] = one_br['bathrooms'].replace('1.5 bathooms', '1.5')
# one_br['bathrooms'] = one_br['bathrooms'].replace('1 shared bathroom', '1')
# one_br['bathrooms'] = one_br['bathrooms'].replace('0 bathrooms', '1')
# one_br['bathrooms'] = one_br['bathrooms'].replace('Private toilet with sink', '1')
# one_br['bathrooms'] = one_br['bathrooms'].replace('Kitchen', '1')
# one_br['bathrooms'] = one_br['bathrooms'].replace('Toilet with sink', '1')
# one_br['bathrooms'] = one_br['bathrooms'].replace('0 shared bathrooms', '1')
# one_br['bathrooms'] = one_br['bathrooms'].replace('1.5 shared bathrooms', '1.5')
# one_br['bathrooms'] = one_br['bathrooms'].replace(' bathrooms*', '', regex=True).astype(float)
one_br.bathrooms.value_counts()
# Out:
# 1.0    891
# 1.5     39
# 2.0     11
# 3.5      1
# Name: bathrooms, dtype: int64

# %%
# one bedrooms number of bathrooms price diff
one_bath = one_br[one_br['bathrooms'] == 1.0]
one_half_bath = one_br[one_br['bathrooms'] == 1.5]
two_bath = one_br[one_br['bathrooms'] == 2.0]

sns.kdeplot(data=one_bath, x='price', fill=True, alpha=0.2, bw=0.05)
# sns.kdeplot(data=one_half_bath, x='price', fill=True, alpha=0.2)
# sns.kdeplot(data=two_bath, x='price',  fill=True, alpha=0.2)
# plt.show()
# Out:
# C:\Users\bdmul\Anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.05 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
one_br
# Out:
#                                                 name  \
# 0                                             Studio
# 1                         Les Marinas for 2 persons.
# 2     Mini duplex aux Marinas de Deauville - vue mer
# 4                       Charmant appartement vue mer
# 6           Studio Deauville Centre\n  Proche du CID
# ...                                              ...
# 2168       DEAUVILLE - SEA FRONT - JARDIN & TERRASSE
# 2197                              Together,  10 lits
# 2201                               Together,  7 lits
# 2204     Le Green de Deauville, Résidence du Golf***
# 2206                               Together, 12 lits
#
#                                          header  \
# 0               Entire rental unit in Deauville
# 1     Entire rental unit in Deauville-Trouville
# 2                 Entire apartment in Deauville
# 4         Entire apartment in Blonville-sur-Mer
# 6               Entire rental unit in Deauville
# ...

# %%
one_br.guests.value_counts()
# Out:
# 4 guests     527
# 2 guests     263
# 3 guests      92
# 5 guests      39
# 6 guests      12
# 1 guest        4
# 7 guests       3
# 12 guests      1
# 10 guests      1
# Name: guests, dtype: int64

# %%
one_br['guests'] = one_br['guests'].replace(' guests*', '', regex=True).astype(int)
one_br.guests.value_counts()
# Out:
# <ipython-input-319-cab3d70a4159>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_br['guests'] = one_br['guests'].replace(' guests*', '', regex=True).astype(int)
# 4     527
# 2     263
# 3      92
# 5      39
# 6      12
# 1       4
# 7       3
# 10      1
# 12      1
# Name: guests, dtype: int64

# %%
# one bedrooms number of guests price diff
two__three_guests = one_br[one_br['guests'] == 2&3]
four_guests = one_br[one_br['guests'] != 2&3]

# two_bath = one_br[one_br['bathrooms'] == 2.0]

sns.kdeplot(data=two_guests, x='price')
sns.kdeplot(data=four_guests, x='price')
# sns.kdeplot(data=two_bath, x='price')
plt.show()
